# %% [markdown]
# # Convolutional Neural Networks
# ---
# In this notebook, we train a **CNN** to classify spectrogram images of DPN+ and DPN- classes.

# %% [markdown]
# ### Test for [CUDA](http://pytorch.org/docs/stable/cuda.html)
#
# Since these are larger (129x27x3) images, it sill prove useful to speed up training time by using a GPU. CUDA is a parallel computing platform and CUDA Tensors are the same as typical Tensors, only they utilize GPU's for computation.

# %%
import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# ---
# ## Load the Data
#
# All spectrogram images are saved inside the 'data' foler. It has two subfolders, namely, "0" and "1". "0" folder contains images representing DPN- class while "1" foler represents DPN+ class.

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %%
# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20

# %% [markdown]
# ### Define Transformations
# Before loading the training and testing data some transformations are done on them. For both the training, validation and test datasets follwoing transformations are done:
# * Resize 129x27 image to 128x32 images (for easier calculations)
# * All images are normalized to have 0.5 mean and 0.5 standard deviation.
# * Images are horizontally flipped with a probability of 0.5. This done to augment the dataset and strengthening the training process.

# %%
# convert data to a normalized torch.FloatTensor
transforms = transforms.Compose([
    transforms.Resize((128, 32)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# %% [markdown]
# ### Splitting Dataset
# Currently all images are inside the "data" folder. In the following section I split the image data into training, validation and testing groups maintaining a 70:15:15 proportion.

# %%
# choose the training and test datasets
# Loading datasets
data_dir = 'data'
trainPercent, valPercent, testPercent = 0.7, 0.15, 0.15 # has to equal to 1
all_data = datasets.ImageFolder(data_dir, transform=transforms)

# obtain training indices that will be used for validation
num_data = len(all_data)
indices = list(range(num_data))
np.random.shuffle(indices)

# Finding the splitting points
split1, split2 = int(np.floor(trainPercent * num_data)), int(np.floor((trainPercent+valPercent) * num_data))
train_idx, valid_idx, test_idx = indices[:split1], indices[split1:split2], indices[split2:]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)
test_sampler = SubsetRandomSampler(test_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(all_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)

valid_loader = torch.utils.data.DataLoader(all_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)

test_loader = torch.utils.data.DataLoader(all_data, batch_size=batch_size, 
    sampler=test_sampler, num_workers=num_workers)

# %%
# specify the image classes
classes = ['DPN-', 'DPN+']

# %% [markdown]
# ### Visualize a Batch of Training Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# ### View an Image in More Detail
#
# Here, we look at the normalized red, green, and blue (RGB) color channels as three separate, grayscale intensity images.

# %%
rgb_img = np.squeeze(images[3])
channels = ['red channel', 'green channel', 'blue channel']

fig = plt.figure(figsize = (36, 36)) 
for idx in np.arange(rgb_img.shape[0]):
    ax = fig.add_subplot(1, 3, idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap='gray')
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            val = round(img[x][y],2) if img[x][y] !=0 else 0
            ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center', size=8,
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ---
# ## Defining the Network [Architecture](http://pytorch.org/docs/stable/nn.html)
#
#
# #### Output volume for a convolutional layer
# To compute the output size of a given convolutional layer we can perform the following calculation (taken from [Stanford's cs231n course](http://cs231n.github.io/convolutional-networks/#layers)):
# > We can compute the spatial size of the output volume as a function of the input volume size (W), the kernel/filter size (F), the stride with which they are applied (S), and the amount of zero padding used (P) on the border. The correct formula for calculating how many neurons define the output_W is given by `(W−F+2P)/S+1`.
#
# For example for a 7x7 input and a 3x3 filter with stride 1 and pad 0 we would get a 5x5 output. With stride 2 we would get a 3x3 output.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # convolutional layer (sees 128x32x3 image tensor)
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1) 
        # convolutional layer (sees 64x16x16 tensor)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1) 
        # convolutional layer (sees 32x8x32 tensor)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1) 
        # convolutional layer (sees 16x4x64 tensor)
        self.conv4 = nn.Conv2d(64, 128, 3, padding=1)
        # convolutional layer (sees 8x2x128 tensor)
        self.conv5 = nn.Conv2d(128, 256, 3, padding=1)
        # output: 4*1*256
        
        
        # max pooling layer
        self.pool = nn.MaxPool2d(2, 2)
        # linear layer (4*1*256 -> 512)
        self.fc1 = nn.Linear(4*1*256, 512)
        # linear layer (512 -> 256)
        self.fc2 = nn.Linear(512, 256)
        # linear layer (256 -> 2)
        self.fc3 = nn.Linear(256, 2)
        # dropout layer (p=0.25)
        self.dropout = nn.Dropout(0.25)

    def forward(self, x):
        # add sequence of convolutional and max pooling layers
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = self.pool(F.relu(self.conv4(x)))
        x = self.pool(F.relu(self.conv5(x)))
        # flatten image input
        x = x.view(-1, 4*1*256)
        # add dropout layer
        x = self.dropout(x)
        # add 1st hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.relu(self.fc2(x))
        # add dropout layer
        x = self.dropout(x)
        # add 3nd hidden layer without relu
        x = self.fc3(x)
        
        return x

# create a complete CNN
model = Net()
print(model)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=2, bias=True)
#   (dropout): Dropout(p=0.25)
# )

# %% [markdown]
# ### Specify [Loss Function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [Optimizer](http://pytorch.org/docs/stable/optim.html)
#
# I chose Cross-Entropy Loss as loss function and Stochastic Gradient Descent as my optimizer for this problem.
# I set the learning rate to 0.01.

# %%
import torch.optim as optim

# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = optim.SGD(model.parameters(), lr=0.02)

# %% [markdown]
# ---
# ## Train the Network
#
# Training the model with 50 epochs.
# While training the model weights will be saved whenever the validation loss decreases. In this way, after the training is done, we will have the best model saved.

# %%
# number of epochs to train the model
n_epochs = 100 # you may increase this number to train a final model

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.484767 	Validation Loss: 0.103869
# Validation loss decreased (inf --> 0.103869).  Saving model ...
# Epoch: 2 	Training Loss: 0.484737 	Validation Loss: 0.103865
# Validation loss decreased (0.103869 --> 0.103865).  Saving model ...
# Epoch: 3 	Training Loss: 0.484731 	Validation Loss: 0.103878
# Epoch: 4 	Training Loss: 0.484657 	Validation Loss: 0.103871
# Epoch: 5 	Training Loss: 0.484629 	Validation Loss: 0.103882
# Epoch: 6 	Training Loss: 0.484731 	Validation Loss: 0.103908
# Epoch: 7 	Training Loss: 0.484740 	Validation Loss: 0.103859
# Validation loss decreased (0.103865 --> 0.103859).  Saving model ...
# Epoch: 8 	Training Loss: 0.484624 	Validation Loss: 0.103929
# Epoch: 9 	Training Loss: 0.484741 	Validation Loss: 0.103868
# Epoch: 10 	Training Loss: 0.484708 	Validation Loss: 0.103855
# Validation loss decreased (0.103859 --> 0.103855).  Saving model ...
# Epoch: 11 	Training Loss: 0.484693 	Validation Loss: 0.103923
# Epoch: 12 	Training Loss: 0.484715 	Validation Loss: 0.103849
# Validation loss decreased (0.103855 --> 0.103849).  Saving model ...
# Epoch: 13 	Training Loss: 0.484562 	Validation Loss: 0.103895
# Epoch: 14 	Training Loss: 0.484720 	Validation Loss: 0.103904
# Epoch: 15 	Training Loss: 0.484726 	Validation Loss: 0.103864
# Epoch: 16 	Training Loss: 0.484593 	Validation Loss: 0.103827
# Validation loss decreased (0.103849 --> 0.103827).  Saving model ...
# Epoch: 17 	Training Loss: 0.484631 	Validation Loss: 0.103820
# Validation loss decreased (0.103827 --> 0.103820).  Saving model ...
# Epoch: 18 	Training Loss: 0.484537 	Validation Loss: 0.103823
# Epoch: 19 	Training Loss: 0.484367 	Validation Loss: 0.103772
# Validation loss decreased (0.103820 --> 0.103772).  Saving model ...
# Epoch: 20 	Training Loss: 0.484254 	Validation Loss: 0.103715
# Validation loss decreased (0.103772 --> 0.103715).  Saving model ...
# Epoch: 21 	Training Loss: 0.483888 	Validation Loss: 0.103551
# Validation loss decreased (0.103715 --> 0.103551).  Saving model ...
# Epoch: 22 	Training Loss: 0.483384 	Validation Loss: 0.103200
# Validation loss decreased (0.103551 --> 0.103200).  Saving model ...
# Epoch: 23 	Training Loss: 0.482126 	Validation Loss: 0.103110
# Validation loss decreased (0.103200 --> 0.103110).  Saving model ...
# Epoch: 24 	Training Loss: 0.480002 	Validation Loss: 0.102472
# Validation loss decreased (0.103110 --> 0.102472).  Saving model ...
# Epoch: 25 	Training Loss: 0.477518 	Validation Loss: 0.101273
# Validation loss decreased (0.102472 --> 0.101273).  Saving model ...
# Epoch: 26 	Training Loss: 0.475210 	Validation Loss: 0.101068
# Validation loss decreased (0.101273 --> 0.101068).  Saving model ...
# Epoch: 27 	Training Loss: 0.471016 	Validation Loss: 0.101220
# Epoch: 28 	Training Loss: 0.469158 	Validation Loss: 0.099963
# Validation loss decreased (0.101068 --> 0.099963).  Saving model ...
# Epoch: 29 	Training Loss: 0.466622 	Validation Loss: 0.101703
# Epoch: 30 	Training Loss: 0.463901 	Validation Loss: 0.098935
# Validation loss decreased (0.099963 --> 0.098935).  Saving model ...
# Epoch: 31 	Training Loss: 0.461484 	Validation Loss: 0.098461
# Validation loss decreased (0.098935 --> 0.098461).  Saving model ...
# Epoch: 32 	Training Loss: 0.457975 	Validation Loss: 0.097404
# Validation loss decreased (0.098461 --> 0.097404).  Saving model ...
# Epoch: 33 	Training Loss: 0.455012 	Validation Loss: 0.096359
# Validation loss decreased (0.097404 --> 0.096359).  Saving model ...
# Epoch: 34 	Training Loss: 0.451365 	Validation Loss: 0.094351
# Validation loss decreased (0.096359 --> 0.094351).  Saving model ...
# Epoch: 35 	Training Loss: 0.446564 	Validation Loss: 0.093845
# Validation loss decreased (0.094351 --> 0.093845).  Saving model ...
# Epoch: 36 	Training Loss: 0.443009 	Validation Loss: 0.093487
# Validation loss decreased (0.093845 --> 0.093487).  Saving model ...
# Epoch: 37 	Training Loss: 0.436614 	Validation Loss: 0.091178
# Validation loss decreased (0.093487 --> 0.091178).  Saving model ...
# Epoch: 38 	Training Loss: 0.432994 	Validation Loss: 0.092311
# Epoch: 39 	Training Loss: 0.428153 	Validation Loss: 0.088600
# Validation loss decreased (0.091178 --> 0.088600).  Saving model ...
# Epoch: 40 	Training Loss: 0.422826 	Validation Loss: 0.088389
# Validation loss decreased (0.088600 --> 0.088389).  Saving model ...
# Epoch: 41 	Training Loss: 0.419156 	Validation Loss: 0.088079
# Validation loss decreased (0.088389 --> 0.088079).  Saving model ...
# Epoch: 42 	Training Loss: 0.413976 	Validation Loss: 0.089519
# Epoch: 43 	Training Loss: 0.409192 	Validation Loss: 0.086324
# Validation loss decreased (0.088079 --> 0.086324).  Saving model ...
# Epoch: 44 	Training Loss: 0.406837 	Validation Loss: 0.086512
# Epoch: 45 	Training Loss: 0.400776 	Validation Loss: 0.085212
# Validation loss decreased (0.086324 --> 0.085212).  Saving model ...
# Epoch: 46 	Training Loss: 0.397267 	Validation Loss: 0.084753
# Validation loss decreased (0.085212 --> 0.084753).  Saving model ...
# Epoch: 47 	Training Loss: 0.391321 	Validation Loss: 0.083838
# Validation loss decreased (0.084753 --> 0.083838).  Saving model ...
# Epoch: 48 	Training Loss: 0.387330 	Validation Loss: 0.084270
# Epoch: 49 	Training Loss: 0.383682 	Validation Loss: 0.080820
# Validation loss decreased (0.083838 --> 0.080820).  Saving model ...
# Epoch: 50 	Training Loss: 0.378308 	Validation Loss: 0.087991
# Epoch: 51 	Training Loss: 0.374009 	Validation Loss: 0.078264
# Validation loss decreased (0.080820 --> 0.078264).  Saving model ...
# Epoch: 52 	Training Loss: 0.368999 	Validation Loss: 0.080899
# Epoch: 53 	Training Loss: 0.365571 	Validation Loss: 0.079429
# Epoch: 54 	Training Loss: 0.360018 	Validation Loss: 0.080727
# Epoch: 55 	Training Loss: 0.356542 	Validation Loss: 0.083585
# Epoch: 56 	Training Loss: 0.349855 	Validation Loss: 0.077978
# Validation loss decreased (0.078264 --> 0.077978).  Saving model ...
# Epoch: 57 	Training Loss: 0.344292 	Validation Loss: 0.071184
# Validation loss decreased (0.077978 --> 0.071184).  Saving model ...
# Epoch: 58 	Training Loss: 0.338441 	Validation Loss: 0.072698
# Epoch: 59 	Training Loss: 0.329436 	Validation Loss: 0.066182
# Validation loss decreased (0.071184 --> 0.066182).  Saving model ...
# Epoch: 60 	Training Loss: 0.322916 	Validation Loss: 0.072205
# Epoch: 61 	Training Loss: 0.314590 	Validation Loss: 0.063795
# Validation loss decreased (0.066182 --> 0.063795).  Saving model ...
# Epoch: 62 	Training Loss: 0.308743 	Validation Loss: 0.065180
# Epoch: 63 	Training Loss: 0.295763 	Validation Loss: 0.072156
# Epoch: 64 	Training Loss: 0.290408 	Validation Loss: 0.059597
# Validation loss decreased (0.063795 --> 0.059597).  Saving model ...
# Epoch: 65 	Training Loss: 0.279040 	Validation Loss: 0.057120
# Validation loss decreased (0.059597 --> 0.057120).  Saving model ...
# Epoch: 66 	Training Loss: 0.270455 	Validation Loss: 0.056716
# Validation loss decreased (0.057120 --> 0.056716).  Saving model ...
# Epoch: 67 	Training Loss: 0.263394 	Validation Loss: 0.054616
# Validation loss decreased (0.056716 --> 0.054616).  Saving model ...
# Epoch: 68 	Training Loss: 0.258956 	Validation Loss: 0.055815
# Epoch: 69 	Training Loss: 0.250299 	Validation Loss: 0.060661
# Epoch: 70 	Training Loss: 0.246613 	Validation Loss: 0.054001
# Validation loss decreased (0.054616 --> 0.054001).  Saving model ...
# Epoch: 71 	Training Loss: 0.239671 	Validation Loss: 0.050104
# Validation loss decreased (0.054001 --> 0.050104).  Saving model ...
# Epoch: 72 	Training Loss: 0.232422 	Validation Loss: 0.048687
# Validation loss decreased (0.050104 --> 0.048687).  Saving model ...
# Epoch: 73 	Training Loss: 0.227423 	Validation Loss: 0.047728
# Validation loss decreased (0.048687 --> 0.047728).  Saving model ...
# Epoch: 74 	Training Loss: 0.222134 	Validation Loss: 0.046066
# Validation loss decreased (0.047728 --> 0.046066).  Saving model ...
# Epoch: 75 	Training Loss: 0.216996 	Validation Loss: 0.047628
# Epoch: 76 	Training Loss: 0.214073 	Validation Loss: 0.048149
# Epoch: 77 	Training Loss: 0.206624 	Validation Loss: 0.044752
# Validation loss decreased (0.046066 --> 0.044752).  Saving model ...
# Epoch: 78 	Training Loss: 0.205816 	Validation Loss: 0.049370
# Epoch: 79 	Training Loss: 0.195296 	Validation Loss: 0.043471
# Validation loss decreased (0.044752 --> 0.043471).  Saving model ...
# Epoch: 80 	Training Loss: 0.197377 	Validation Loss: 0.048910
# Epoch: 81 	Training Loss: 0.189264 	Validation Loss: 0.045363
# Epoch: 82 	Training Loss: 0.187721 	Validation Loss: 0.046660
# Epoch: 83 	Training Loss: 0.183336 	Validation Loss: 0.040099
# Validation loss decreased (0.043471 --> 0.040099).  Saving model ...
# Epoch: 84 	Training Loss: 0.178623 	Validation Loss: 0.042645
# Epoch: 85 	Training Loss: 0.173919 	Validation Loss: 0.041256
# Epoch: 86 	Training Loss: 0.171256 	Validation Loss: 0.041040
# Epoch: 87 	Training Loss: 0.167848 	Validation Loss: 0.046120
# Epoch: 88 	Training Loss: 0.165867 	Validation Loss: 0.044785
# Epoch: 89 	Training Loss: 0.163237 	Validation Loss: 0.043172
# Epoch: 90 	Training Loss: 0.158686 	Validation Loss: 0.038291
# Validation loss decreased (0.040099 --> 0.038291).  Saving model ...
# Epoch: 91 	Training Loss: 0.154168 	Validation Loss: 0.039746
# Epoch: 92 	Training Loss: 0.151495 	Validation Loss: 0.052190
# Epoch: 93 	Training Loss: 0.151414 	Validation Loss: 0.038745
# Epoch: 94 	Training Loss: 0.146587 	Validation Loss: 0.047070
# Epoch: 95 	Training Loss: 0.143008 	Validation Loss: 0.043858
# Epoch: 96 	Training Loss: 0.143442 	Validation Loss: 0.040729
# Epoch: 97 	Training Loss: 0.135952 	Validation Loss: 0.042610
# Epoch: 98 	Training Loss: 0.134157 	Validation Loss: 0.036451
# Validation loss decreased (0.038291 --> 0.036451).  Saving model ...
# Epoch: 99 	Training Loss: 0.135927 	Validation Loss: 0.037488
# Epoch: 100 	Training Loss: 0.128973 	Validation Loss: 0.039305

# %% [markdown]
# ###  Load the Model with the Lowest Validation Loss

# %%
model.load_state_dict(torch.load('model_cifar.pt'))

# %% [markdown]
# ---
# ## Test the Trained Network
#
# Testing trained model on previously unseen data! The model with the lowest validation loss is selected.

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(2))
class_total = list(0. for i in range(2))

model.eval()
# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(2):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.039931
#
# Test Accuracy of  DPN-: 88% (1742/1976)
# Test Accuracy of  DPN+: 88% (1569/1764)
#
# Test Accuracy (Overall): 88% (3311/3740)

# %% [markdown]
# ### Visualize Sample Test Results

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
